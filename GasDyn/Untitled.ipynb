# %%
from matplotlib.pyplot import *
import numpy as np
# %matplotlib notebook

N = 1000
Nx = 2000
H = 1
T = 1

a = 0.5
h =  H / Nx
t = T / N

d = a * t / h

X = np.arange(0, H, h)
U = [3] * len(X)
U[0] = 5
UU = []

subplot(111)
#axis([0, 1, 3, 5.01])
ln, = plot(X, U)

for time in np.arange(0, T, t):
    i = 0
    i += 1
    UU = np.copy(U)
    
    for i in range(1, Nx):
        U[i] = 1/(1+d)*(UU_0 + d*UU[i-1])
    U[i]  = UU_0 
    ln.set_data(X, U)
    gcf().canvas.draw()

    y = 1
    U[y] = 5
    y += 1
# Out:
# <img src="data:image/png;base64,..." width="640">
