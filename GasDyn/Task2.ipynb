# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# Задаем форму сопла

# %%
N = 1000
a_0 = 0.5
x_0 = 0.5
X = np.linspace(0, 1, N)
a = lambda x: a_0 + (1 - a_0)*(1- x/x_0)**2
A = a(X)

h = (X[1] - X[0])/N
# Out:
# [1.         0.998      0.99600401 0.99401203 0.99202406 0.99004009
#  0.98806013 0.98608418 0.98411224 0.98214431 0.98018038 0.97822046
#  0.97626455 0.97431265 0.97236476 0.97042087 0.96848099 0.96654512
#  0.96461326 0.96268541 0.96076156 0.95884172 0.95692589 0.95501407
#  0.95310626 0.95120245 0.94930266 0.94740687 0.94551508 0.94362731
#  0.94174355 0.93986379 0.93798804 0.9361163  0.93424856 0.93238484
#  0.93052512 0.92866941 0.92681771 0.92497002 0.92312633 0.92128665
#  0.91945098 0.91761932 0.91579167 0.91396802 0.91214838 0.91033276
#  0.90852113 0.90671352 0.90490991 0.90311032 0.90131473 0.89952315
#  0.89773557 0.89595201 0.89417245 0.8923969  0.89062536 0.88885783
#  0.8870943  0.88533478 0.88357927 0.88182777 0.88008028 0.8783368
#  0.87659732 0.87486185 0.87313039 0.87140293 0.86967949 0.86796005
#  0.86624462 0.8645332  0.86282579 0.86112238 0.85942299 0.8577276
#  0.85603622 0.85434884 0.85266548 0.85098612 0.84931077 0.84763943
# ...

# %% [markdown]
# Задаем трехстрочные списки с параметрами на входе и выходе

# %%
Q_1 = np.zeros(3)
Q_1[0] = 1
Q_1[1] = 1.0237498
Q_1[2] = 8

Q_2 = np.zeros(3)
Q_2[0] = 0.1933880
Q_2[1] = 5.2937598
Q_2[2] = 0.8018469

# %%
Q = np.zeros((3,N+1))
F = np.zeros((3,N+1))
S = np.zeros((3,N+1))

# %%
def lax():
