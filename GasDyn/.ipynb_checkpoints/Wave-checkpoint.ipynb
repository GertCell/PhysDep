# %%
from matplotlib.pyplot import *
import numpy as np
# %matplotlib notebook

N = 1000
Nx = 2000
H = 1
T = 1

a = 0.5
h =  H / Nx
t = T / N

d = a * t / h

X = np.arange(0, H, h)
U = [3] * len(X)
U[0] = 5
U1 = np.copy(U)
UU = []

subplot(111)
#axis([0, 1, 3, 5.01])
ln, = plot(X, U)
ln1, = plot(X, U1)

for time in np.arange(0, T, t):
    UU = np.copy(U)

    for i in range(1, Nx):
        U[i] = UU[i] + d*(UU[i - 1] - UU[i])

    ln.set_data(X, U)
    gcf().canvas.draw()

    y = 1
    U[y] = 5
    y += 1


for time in np.arange(0, T, t):
    
    UU = np.copy(U1)

    for i in range(1, Nx):
        U1[i] = UU[i] + d*(UU[i - 1] - UU[i])

    ln.set_data(X, U1)
    gcf().canvas.draw()

    y = 1
    U1[y] = 5
    y += 1
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 25>()
#      29     U[i] = UU[i] + d*(UU[i - 1] - UU[i])
#      31 ln.set_data(X, U)
# ---> 32 gcf().canvas.draw()
#      34 y = 1
#      35 U[y] = 5
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_webagg_core.py:188, in FigureCanvasWebAggCore.draw(self)
#     186 self._png_is_old = True
#     187 try:
# --> 188     super().draw()
#     189 finally:
#     190     self.manager.refresh_all()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:436, in FigureCanvasAgg.draw(self)
#     432 # Acquire a lock on the shared font cache.
#     433 with RendererAgg.lock, \
#     434      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435       else nullcontext()):
# ...
